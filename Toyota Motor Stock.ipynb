# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # EDA

# %%
data=pd.read_csv(r"C:\Users\ASUS\Downloads\Toyota_Data.csv")
data.head(5)
# Out:
#          Date  Adj Close     Close      High       Low      Open  Volume
# 0  1980-03-17   2.296798  3.291227  3.344743  3.291227  0.000000   41109
# 1  1980-03-18   2.306134  3.304606  3.358122  3.304606  0.000000    9343
# 2  1980-03-19   2.306134  3.304606  3.304606  3.304606  3.304606       0
# 3  1980-03-20   2.306134  3.304606  3.358122  3.304606  0.000000   10277
# 4  1980-03-21   2.362154  3.384880  3.438396  3.384880  0.000000    8409

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11291 entries, 0 to 11290
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       11291 non-null  object
#  1   Adj Close  11291 non-null  float64
#  2   Close      11291 non-null  float64
#  3   High       11291 non-null  float64
#  4   Low        11291 non-null  float64
#  5   Open       11291 non-null  float64
#  6   Volume     11291 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 617.6+ KB

# %%
data["Date"]=pd.to_datetime(data["Date"])
data.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="Date",y="Close",data=data,color="green")
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %% [markdown]
# # Data Prerpocessing

# %%
df=data[["Close"]].values

# %%
scaler=MinMaxScaler(feature_range=(0,1))
scaler_data=scaler.fit_transform(df)

# %%
def create_sequence (df,sequence_length):
    X=[]
    y=[]
    for i in range (sequence_length,len(df)):
        X.append(df[i-sequence_length:i, 0])
        y.append(df[i,0])
    return np.array(X),np.array(y)

# %%
sequence_length=10

# %%
X,y=create_sequence(scaler_data,sequence_length)

# %%
X=X.reshape((X.shape[0],X.shape[1],1))
print(X.shape,y.shape)
# Out:
# (11281, 10, 1) (11281,)

# %% [markdown]
# # LSTM Model

# %%
model=Sequential()

# %%
model.add(LSTM(50,activation="relu",input_shape=(X.shape[1],X.shape[2])))

# %%
model.add(Dropout(0.2))

# %%
model.add(Dense(1))

# %%
model.compile(optimizer="adam",loss="mean_squared_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                10400
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X,y,epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 353/353 [==============================] - 5s 6ms/step - loss: 0.0077
# Epoch 2/100
# 353/353 [==============================] - 2s 6ms/step - loss: 0.0018
# Epoch 3/100
# 353/353 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 4/100
# 353/353 [==============================] - 2s 6ms/step - loss: 0.0012
# Epoch 5/100
# 353/353 [==============================] - 2s 6ms/step - loss: 0.0011
# Epoch 6/100
# 353/353 [==============================] - 2s 6ms/step - loss: 0.0011
# Epoch 7/100
# 353/353 [==============================] - 2s 6ms/step - loss: 9.6110e-04
# Epoch 8/100
# 353/353 [==============================] - 2s 6ms/step - loss: 9.1476e-04
# Epoch 9/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.9283e-04
# Epoch 10/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.8775e-04
# Epoch 11/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.8239e-04
# Epoch 12/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.5057e-04
# Epoch 13/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.9462e-04
# Epoch 14/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.9069e-04
# Epoch 15/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.7856e-04
# Epoch 16/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.5774e-04
# Epoch 17/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.9927e-04
# Epoch 18/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.7224e-04
# Epoch 19/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.6282e-04
# Epoch 20/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.8150e-04
# Epoch 21/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.5630e-04
# Epoch 22/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3004e-04
# Epoch 23/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2043e-04
# Epoch 24/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2376e-04
# Epoch 25/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.6286e-04
# Epoch 26/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4541e-04
# Epoch 27/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2880e-04
# Epoch 28/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.6616e-04
# Epoch 29/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2211e-04
# Epoch 30/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4143e-04
# Epoch 31/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3372e-04
# Epoch 32/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4154e-04
# Epoch 33/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2919e-04
# Epoch 34/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3598e-04
# Epoch 35/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.5991e-04
# Epoch 36/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3542e-04
# Epoch 37/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1313e-04
# Epoch 38/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0744e-04
# Epoch 39/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2305e-04
# Epoch 40/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2115e-04
# Epoch 41/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4345e-04
# Epoch 42/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2199e-04
# Epoch 43/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1525e-04
# Epoch 44/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.5406e-04
# Epoch 45/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4829e-04
# Epoch 46/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.6040e-04
# Epoch 47/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0114e-04
# Epoch 48/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.8066e-04
# Epoch 49/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4618e-04
# Epoch 50/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.5233e-04
# Epoch 51/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.7852e-04
# Epoch 52/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1988e-04
# Epoch 53/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3080e-04
# Epoch 54/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.9410e-04
# Epoch 55/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4929e-04
# Epoch 56/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2624e-04
# Epoch 57/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0153e-04
# Epoch 58/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0430e-04
# Epoch 59/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1450e-04
# Epoch 60/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0628e-04
# Epoch 61/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2767e-04
# Epoch 62/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4003e-04
# Epoch 63/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1522e-04
# Epoch 64/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2097e-04
# Epoch 65/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0409e-04
# Epoch 66/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2510e-04
# Epoch 67/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1541e-04
# Epoch 68/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3370e-04
# Epoch 69/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.7175e-04
# Epoch 70/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2019e-04
# Epoch 71/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.9891e-04
# Epoch 72/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3003e-04
# Epoch 73/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.8917e-04
# Epoch 74/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1033e-04
# Epoch 75/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3937e-04
# Epoch 76/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2738e-04
# Epoch 77/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.9737e-04
# Epoch 78/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4474e-04
# Epoch 79/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.9654e-04
# Epoch 80/100
# 353/353 [==============================] - 2s 7ms/step - loss: 8.0037e-04
# Epoch 81/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4356e-04
# Epoch 82/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3119e-04
# Epoch 83/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.6501e-04
# Epoch 84/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1741e-04
# Epoch 85/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.9355e-04
# Epoch 86/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1554e-04
# Epoch 87/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0339e-04
# Epoch 88/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.3038e-04
# Epoch 89/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.9370e-04
# Epoch 90/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.8903e-04
# Epoch 91/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0852e-04
# Epoch 92/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0107e-04
# Epoch 93/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.2702e-04
# Epoch 94/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1165e-04
# Epoch 95/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.1981e-04
# Epoch 96/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.7560e-04
# Epoch 97/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.4458e-04
# Epoch 98/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0132e-04
# Epoch 99/100
# 353/353 [==============================] - 2s 6ms/step - loss: 8.0269e-04
# Epoch 100/100
# 353/353 [==============================] - 2s 6ms/step - loss: 7.9050e-04

# %% [markdown]
# # Model Evaluation

# %%
loss=model.evaluate(X,y)
print("Model Loss:",loss)
# Out:
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 4.4215e-05
# Model Loss: 6.245801341719925e-05

# %% [markdown]
# # Model Prediction

# %%
predictions=model.predict(X)
predictions=scaler.inverse_transform(predictions)
print(predictions[:10])
# Out:
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# [[5.111334 ]
#  [5.105022 ]
#  [5.0819373]
#  [5.059314 ]
#  [5.0441227]
#  [5.0322824]
#  [5.0236955]
#  [5.054198 ]
#  [5.0835414]
#  [5.0990777]]

# %%
actual_values=scaler.inverse_transform(y.reshape(-1,1))

# %% [markdown]
# # Actual Vs Predicted

# %%
plt.figure(figsize=(10, 6))
plt.plot(actual_values, label="Actual Values",color="blue")  
plt.plot(predictions, label="Predicted Values",color="orange") 
plt.legend()
plt.title('LSTM Prediction vs Actual Values')  
plt.xlabel('Time Step') 
plt.ylabel('Value')  
plt.show()
